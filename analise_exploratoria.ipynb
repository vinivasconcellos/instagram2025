# %%
import pandas as pd
import numpy as np
import os
import sys
sys.path.append("../src")
from limpeza_dados import converter_k, formatar_mes
from calculo_engajamento import calcular_engajamento
from medias import media_por_grupo
from medias_grupo import resumo_max_min_por_grupo
from categorias import categorizar_post
from outliers import detectar_outliers_iqr, sem_outliers_iqr

df_postagens2025 = pd.read_excel("Posts_2025.xlsx")

# %%
#tratamento
colunas = ["Curtidas", "Coment.", "Compart.", "Salvos", "Visualiz.", "Alcance", "Visitas", "Seguid."]
for col in colunas:
    df_postagens2025[col] = df_postagens2025[col].apply(converter_k)

display(df_postagens2025)


df_postagens2025 = formatar_mes(df_postagens2025)
display(df_postagens2025.head())
display(df_postagens2025.info())
# Out:
#      Mês      Título / Tema do Post  Formato  Curtidas  Coment.  Compart.  \
# 0    JAN     Glicemia alta gestação     Post        26        0         8
# 1    JAN           Castanha p/ bebê     Post        17        0         7
# 2    JAN         Como oferecer maçã    Reels        26        0         8
# 3    JAN              Leite e fezes    Reels        13        0         1
# 4    JAN            Água para bebês     Post        36        6        16
# ..   ...                        ...      ...       ...      ...       ...
# 97   NOV  Lista: Não dar até 2 anos     Post       132        4        46
# 98   NOV              Qual iogurte?    Reels        18        0        10
# 99   DEZ      Pasta amendoim indico  Carros.        33        3         6
# 100  DEZ         Por que não banana  Carros.        38        1        17
# 101  DEZ                 Post Natal     Post        26        0         0
#
#      Salvos  Visualiz.  Alcance  Visitas  Seguid.
# 0         9       5283        0       89       12
# 1         7       3143        0        2        0
# 2        10       5654        0        0        2
# 3         2       1648        0        0        0
# 4        33       5003        0       21        1
# ..      ...        ...      ...      ...      ...
# 97       18      10283        0      124       18
# 98        6       1993        0        0        0
# 99       29       6737        0      147       23
# 100       8       9123        0      160       18
# 101       1       1760        0        3        0
#
# [102 rows x 11 columns]
#    Mês   Título / Tema do Post Formato  Curtidas  Coment.  Compart.  Salvos  \
# 0  Jan  glicemia alta gestação    Post        26        0         8       9
# 1  Jan        castanha p/ bebê    Post        17        0         7       7
# 2  Jan      como oferecer maçã   Reels        26        0         8      10
# 3  Jan           leite e fezes   Reels        13        0         1       2
# 4  Jan         água para bebês    Post        36        6        16      33
#
#    Visualiz.  Alcance  Visitas  Seguid.
# 0       5283        0       89       12
# 1       3143        0        2        0
# 2       5654        0        0        2
# 3       1648        0        0        0
# 4       5003        0       21        1
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Mês                    102 non-null    object
#  1   Título / Tema do Post  102 non-null    object
#  2   Formato                102 non-null    object
#  3   Curtidas               102 non-null    int64
#  4   Coment.                102 non-null    int64
#  5   Compart.               102 non-null    int64
#  6   Salvos                 102 non-null    int64
#  7   Visualiz.              102 non-null    int64
#  8   Alcance                102 non-null    int64
#  9   Visitas                102 non-null    int64
#  10  Seguid.                102 non-null    int64
# dtypes: int64(8), object(3)
# memory usage: 8.9+ KB
# None

# %%
display(df_postagens2025)
#filtragem
colunas = ["Curtidas", "Coment.", "Compart.", "Salvos", "Visualiz.", "Alcance", "Visitas", "Seguid.", "Engajamento"]

#cálculo engajamento:
df_postagens2025 = calcular_engajamento(df_postagens2025)
display(df_postagens2025)

#médias
df_medias = media_por_grupo(df_postagens2025, colunas)
display(df_medias.round(2))

#qual formato teve o maior e o menor valor médio de acordo com a métrica
df_resumo = resumo_max_min_por_grupo(df_postagens2025, colunas, grupo="Formato")
display(df_resumo.round(2))
# Out:
#      Mês      Título / Tema do Post  Formato  Curtidas  Coment.  Compart.  \
# 0    Jan     glicemia alta gestação     Post        26        0         8
# 1    Jan           castanha p/ bebê     Post        17        0         7
# 2    Jan         como oferecer maçã    Reels        26        0         8
# 3    Jan              leite e fezes    Reels        13        0         1
# 4    Jan            água para bebês     Post        36        6        16
# ..   ...                        ...      ...       ...      ...       ...
# 97   Nov  lista: não dar até 2 anos     Post       132        4        46
# 98   Nov              qual iogurte?    Reels        18        0        10
# 99   Dez      pasta amendoim indico  Carros.        33        3         6
# 100  Dez         por que não banana  Carros.        38        1        17
# 101  Dez                 post natal     Post        26        0         0
#
#      Salvos  Visualiz.  Alcance  Visitas  Seguid.
# 0         9       5283        0       89       12
# 1         7       3143        0        2        0
# 2        10       5654        0        0        2
# 3         2       1648        0        0        0
# 4        33       5003        0       21        1
# ..      ...        ...      ...      ...      ...
# 97       18      10283        0      124       18
# 98        6       1993        0        0        0
# 99       29       6737        0      147       23
# 100       8       9123        0      160       18
# 101       1       1760        0        3        0
#
# [102 rows x 11 columns]
#      Mês      Título / Tema do Post  Formato  Curtidas  Coment.  Compart.  \
# 0    Jan     glicemia alta gestação     Post        26        0         8
# 1    Jan           castanha p/ bebê     Post        17        0         7
# 2    Jan         como oferecer maçã    Reels        26        0         8
# 3    Jan              leite e fezes    Reels        13        0         1
# 4    Jan            água para bebês     Post        36        6        16
# ..   ...                        ...      ...       ...      ...       ...
# 97   Nov  lista: não dar até 2 anos     Post       132        4        46
# 98   Nov              qual iogurte?    Reels        18        0        10
# 99   Dez      pasta amendoim indico  Carros.        33        3         6
# 100  Dez         por que não banana  Carros.        38        1        17
# 101  Dez                 post natal     Post        26        0         0
#
#      Salvos  Visualiz.  Alcance  Visitas  Seguid.  Engajamento
# 0         9       5283        0       89       12           43
# 1         7       3143        0        2        0           31
# 2        10       5654        0        0        2           44
# 3         2       1648        0        0        0           16
# 4        33       5003        0       21        1           91
# ..      ...        ...      ...      ...      ...          ...
# 97       18      10283        0      124       18          200
# 98        6       1993        0        0        0           34
# 99       29       6737        0      147       23           71
# 100       8       9123        0      160       18           64
# 101       1       1760        0        3        0           27
#
# [102 rows x 12 columns]
#    Formato  Curtidas  Coment.  Compart.  Salvos  Visualiz.   Alcance  Visitas  \
# 0   Artigo     82.00     0.00      3.33    5.67    5400.67      0.00     2.67
# 1  Carros.    403.17     8.39    622.83   84.96   31282.91   8963.91   167.74
# 2     Foto    193.33     0.00     53.00   39.00    8807.00   4672.67    81.00
# 3     Post    490.27     4.80    578.13   56.62   33293.31  11554.27   171.73
# 4    Reels     25.73     0.96     14.15    6.46    3668.65    490.19     0.00
# 5    Vídeo    159.50    14.00     85.50   22.00    9727.50      0.00     0.00
#
#    Seguid.  Engajamento
# 0     0.00        91.00
# 1    27.87      1119.35
# 2    21.00       285.33
# 3    27.84      1129.82
# 4     1.04        47.31
# 5     1.50       281.00
#        Metrica Maior_Grupo  Maior_Valor Menor_Grupo  Menor_Valor
# 0     Curtidas        Post       490.27       Reels        25.73
# 1      Coment.       Vídeo        14.00      Artigo         0.00
# 2     Compart.     Carros.       622.83      Artigo         3.33
# 3       Salvos     Carros.        84.96      Artigo         5.67
# 4    Visualiz.        Post     33293.31       Reels      3668.65
# 5      Alcance        Post     11554.27      Artigo         0.00
# 6      Visitas        Post       171.73       Reels         0.00
# 7      Seguid.     Carros.        27.87      Artigo         0.00
# 8  Engajamento        Post      1129.82       Reels        47.31

# %%
#categorias

df_postagens2025["Categoria"] = df_postagens2025["Título / Tema do Post"].map(categorizar_post)
display(df_postagens2025)
df_postagens2025.to_excel("postagens_categorizadas_2025.xlsx", index=False)
# Out:
#      Mês      Título / Tema do Post  Formato  Curtidas  Coment.  Compart.  \
# 0    Jan     glicemia alta gestação     Post        26        0         8
# 1    Jan           castanha p/ bebê     Post        17        0         7
# 2    Jan         como oferecer maçã    Reels        26        0         8
# 3    Jan              leite e fezes    Reels        13        0         1
# 4    Jan            água para bebês     Post        36        6        16
# ..   ...                        ...      ...       ...      ...       ...
# 97   Nov  lista: não dar até 2 anos     Post       132        4        46
# 98   Nov              qual iogurte?    Reels        18        0        10
# 99   Dez      pasta amendoim indico  Carros.        33        3         6
# 100  Dez         por que não banana  Carros.        38        1        17
# 101  Dez                 post natal     Post        26        0         0
#
#      Salvos  Visualiz.  Alcance  Visitas  Seguid.  Engajamento  \
# 0         9       5283        0       89       12           43
# 1         7       3143        0        2        0           31
# 2        10       5654        0        0        2           44
# 3         2       1648        0        0        0           16
# 4        33       5003        0       21        1           91
# ..      ...        ...      ...      ...      ...          ...
# 97       18      10283        0      124       18          200
# 98        6       1993        0        0        0           34
# 99       29       6737        0      147       23           71
# 100       8       9123        0      160       18           64
# 101       1       1760        0        3        0           27
#
#                                    Categoria
# 0                       Gestação / Pré-natal
# 1    Alimentação Bebê / Introdução alimentar
# 2    Alimentação Bebê / Introdução alimentar
# 3                        Amamentação / Leite
# 4    Alimentação Bebê / Introdução alimentar
# ..                                       ...
# 97   Alimentação Bebê / Introdução alimentar
# 98                           Perguntas / Q&A
# 99   Alimentação Bebê / Introdução alimentar
# 100  Alimentação Bebê / Introdução alimentar
# 101                                   Outros
#
# [102 rows x 13 columns]

# %%
#outliers

#Detectar outliers de engajamento
outliers_eng = detectar_outliers_iqr(df_postagens2025, coluna="Engajamento")
print("Outliers de Engajamento:")
display(outliers_eng)

#Top categorias presentes nos outliers
top_categorias_outliers_eng = (outliers_eng["Categoria"].value_counts().reset_index())
top_categorias_outliers_eng.columns = ["Categoria", "Qtd_Outliers"]
display(top_categorias_outliers_eng)
# Out:
# Outliers de Engajamento:
#     Mês     Título / Tema do Post  Formato  Curtidas  Coment.  Compart.  \
# 21  Mar  suco após 2 anos (viral)  Carros.      5900      142     12000
# 23  Mar     feto 16 sem (sabores)     Foto       505        0       126
# 43  Jun      ômega 3 feto (viral)     Post      8400       32      5900
# 46  Jul      ganho 1kg até 28 sem     Post       395        0       122
# 52  Jul      não incentive errado     Post       313        2        90
# 58  Jul         dermatite atópica     Post      2065        1        20
# 59  Ago         amamentação vídeo    Vídeo       210        3       112
# 64  Ago       corrida 5km (viral)     Post      1700       18      3100
# 79  Set   saúde vida toda (viral)  Carros.      2400       13      2000
# 92  Out  cafeína gestante (viral)     Post      6800      120     16000
#
#     Salvos  Visualiz.  Alcance  Visitas  Seguid.  Engajamento  \
# 21    1100     240144   193245      435      247        19142
# 23      29      14018    14018      225       60          660
# 43     534     367203        0      286      148        14866
# 46      34         43    35005      126       15          551
# 52      37      26711        0      204       47          442
# 58      36      16229        0      125        9         2122
# 59      43      10890        0        0        3          368
# 64     128      95548        0      170       22         4946
# 79     323     295358        0      750       84         4736
# 92     969     592462   450365      929      233        23889
#
#                                   Categoria
# 21  Alimentação Bebê / Introdução alimentar
# 23                     Gestação / Pré-natal
# 43                     Gestação / Pré-natal
# 46                     Gestação / Pré-natal
# 52  Alimentação Bebê / Introdução alimentar
# 58                          Alergias / APLV
# 59                      Amamentação / Leite
# 64                                   Outros
# 79                     Gestação / Pré-natal
# 92                     Gestação / Pré-natal
#                                  Categoria  Qtd_Outliers
# 0                     Gestação / Pré-natal             5
# 1  Alimentação Bebê / Introdução alimentar             2
# 2                          Alergias / APLV             1
# 3                      Amamentação / Leite             1
# 4                                   Outros             1

# %%
#métricas sem outliers
# quais formatos tiveram melhor engajamento por categoria retirando os outliers

df_analise_categoria_tema_eng_s = sem_outliers_iqr(df_postagens2025, coluna="Engajamento")
display(df_analise_categoria_tema_eng_s)

# quais formatos tiveram melhor engajamento por categoria com outlier
analise_categoria_tema_eng = df_postagens2025[["Formato", "Categoria", "Engajamento"]].groupby(["Categoria", "Formato"]).mean().round(2).sort_values(by=["Categoria", "Engajamento"], ascending=[True, False])
#display(analise_categoria_tema_eng)

# quais formatos tiveram melhor engajamento por categoria sem outlier
analise_categoria_tema_eng_s = df_analise_categoria_tema_eng_s[["Formato", "Categoria", "Engajamento"]].groupby(["Categoria", "Formato"]).mean().round(2).sort_values(by=["Categoria", "Engajamento"], ascending=[True, False])
#display(analise_categoria_tema_eng_s)

# mostrando os dois resultados para comparação
analise_categoria_tema_eng_s = analise_categoria_tema_eng_s.rename(columns={"Engajamento": "Eng_Sem_Outliers"})
analise_categoria_tema_eng = analise_categoria_tema_eng.rename(columns={"Engajamento": "Eng_Com_Outliers"})
df_cat_eng_s_c = analise_categoria_tema_eng.merge(analise_categoria_tema_eng_s, on=["Categoria", "Formato"], how="outer")
df_cat_eng_s_c = df_cat_eng_s_c.fillna(0)

display(df_cat_eng_s_c.sort_values(by=["Categoria", "Eng_Sem_Outliers"], ascending=[True, False]))

# Média de engajamento por categoria sem outliers
df_media_eng_cat_s = df_analise_categoria_tema_eng_s[["Categoria", "Engajamento"]].groupby(["Categoria"]).mean()
df_media_eng_cat_s = df_analise_categoria_tema_eng_s[["Categoria", "Engajamento"]].groupby(["Categoria"]).mean().sort_values(by=["Engajamento", "Categoria"], ascending=[False, True])
df_media_eng_cat_s = df_media_eng_cat_s.reset_index()
df_media_eng_cat_s.columns = ["Categoria", "Media_Eng_Sem_Outliers"]

# Média de engajamento por categoria com outliers
df_media_eng_cat = df_postagens2025[["Categoria", "Engajamento"]].groupby(["Categoria"]).mean()
df_media_eng_cat = df_postagens2025[["Categoria", "Engajamento"]].groupby(["Categoria"]).mean().sort_values(by=["Engajamento", "Categoria"], ascending=[False, True])
df_media_eng_cat = df_media_eng_cat.reset_index()
df_media_eng_cat.columns = ["Categoria", "Media_Eng_Com_Outliers"]

#df_com = df_media_eng_cat.rename(columns={"Engajamento": "Eng_Com_Outliers"})


df_tot = df_media_eng_cat.merge(df_media_eng_cat_s, on=["Categoria"], how="outer")
df_tot = df_tot.fillna(0)
df_tot = df_tot.sort_values(by="Media_Eng_Sem_Outliers", ascending=False)
print("Ordem decrescente de engajamento sem outliers:")
display(df_tot.round(2))
df_tot = df_tot.sort_values(by="Media_Eng_Com_Outliers", ascending=False)
print("Ordem decrescente de engajamento com outliers:")
display(df_tot.round(2))
# Out:
#      Mês      Título / Tema do Post  Formato  Curtidas  Coment.  Compart.  \
# 0    Jan     glicemia alta gestação     Post        26        0         8
# 1    Jan           castanha p/ bebê     Post        17        0         7
# 2    Jan         como oferecer maçã    Reels        26        0         8
# 3    Jan              leite e fezes    Reels        13        0         1
# 4    Jan            água para bebês     Post        36        6        16
# ..   ...                        ...      ...       ...      ...       ...
# 97   Nov  lista: não dar até 2 anos     Post       132        4        46
# 98   Nov              qual iogurte?    Reels        18        0        10
# 99   Dez      pasta amendoim indico  Carros.        33        3         6
# 100  Dez         por que não banana  Carros.        38        1        17
# 101  Dez                 post natal     Post        26        0         0
#
#      Salvos  Visualiz.  Alcance  Visitas  Seguid.  Engajamento  \
# 0         9       5283        0       89       12           43
# 1         7       3143        0        2        0           31
# 2        10       5654        0        0        2           44
# 3         2       1648        0        0        0           16
# 4        33       5003        0       21        1           91
# ..      ...        ...      ...      ...      ...          ...
# 97       18      10283        0      124       18          200
# 98        6       1993        0        0        0           34
# 99       29       6737        0      147       23           71
# 100       8       9123        0      160       18           64
# 101       1       1760        0        3        0           27
#
#                                    Categoria
# 0                       Gestação / Pré-natal
# 1    Alimentação Bebê / Introdução alimentar
# 2    Alimentação Bebê / Introdução alimentar
# 3                        Amamentação / Leite
# 4    Alimentação Bebê / Introdução alimentar
# ..                                       ...
# 97   Alimentação Bebê / Introdução alimentar
# 98                           Perguntas / Q&A
# 99   Alimentação Bebê / Introdução alimentar
# 100  Alimentação Bebê / Introdução alimentar
# 101                                   Outros
#
# [92 rows x 13 columns]
#                                                  Eng_Com_Outliers  \
# Categoria                               Formato
# Alergias / APLV                         Post               785.00
#                                         Reels               35.50
#                                         Carros.             29.00
# Alimentação Bebê / Introdução alimentar Vídeo              194.00
#                                         Foto               176.00
#                                         Post               167.71
#                                         Carros.           2214.22
#                                         Reels               37.20
#                                         Artigo              17.00
# Amamentação / Leite                     Carros.            117.50
#                                         Post                92.88
#                                         Reels               88.50
#                                         Foto                20.00
#                                         Artigo              11.00
#                                         Vídeo              368.00
# Gestação / Pré-natal                    Post              3086.92
#                                         Carros.           1240.25
#                                         Reels               10.00
#                                         Foto               660.00
# Outros                                  Artigo             245.00
#                                         Reels               67.50
#                                         Post              1663.00
# Perguntas / Q&A                         Post                75.00
#                                         Reels               32.67
# Receitas / Comida                       Post                67.33
# Suplementos / Nutrientes                Carros.            106.80
#                                         Reels               27.50
#
#                                                  Eng_Sem_Outliers
# Categoria                               Formato
# Alergias / APLV                         Post               116.50
#                                         Reels               35.50
#                                         Carros.             29.00
# Alimentação Bebê / Introdução alimentar Vídeo              194.00
#                                         Foto               176.00
#                                         Post               146.62
#                                         Carros.             98.25
#                                         Reels               37.20
#                                         Artigo              17.00
# Amamentação / Leite                     Carros.            117.50
#                                         Post                92.88
#                                         Reels               88.50
#                                         Foto                20.00
#                                         Artigo              11.00
#                                         Vídeo                0.00
# Gestação / Pré-natal                    Post                82.40
#                                         Carros.             75.00
#                                         Reels               10.00
#                                         Foto                 0.00
# Outros                                  Artigo             245.00
#                                         Reels               67.50
#                                         Post                21.50
# Perguntas / Q&A                         Post                75.00
#                                         Reels               32.67
# Receitas / Comida                       Post                67.33
# Suplementos / Nutrientes                Carros.            106.80
#                                         Reels               27.50
# Ordem decrescente sem outliers:
#                                  Categoria  Media_Eng_Com_Outliers  \
# 1  Alimentação Bebê / Introdução alimentar                  639.86
# 2                      Amamentação / Leite                  101.82
# 7                 Suplementos / Nutrientes                   84.14
# 4                                   Outros                  688.00
# 3                     Gestação / Pré-natal                 2408.47
# 6                        Receitas / Comida                   67.33
# 0                          Alergias / APLV                  314.12
# 5                          Perguntas / Q&A                   43.25
#
#    Media_Eng_Sem_Outliers
# 1                  101.50
# 2                   85.19
# 7                   84.14
# 4                   79.71
# 3                   75.64
# 6                   67.33
# 0                   55.86
# 5                   43.25
# Ordem decrescente com outliers:
#                                  Categoria  Media_Eng_Com_Outliers  \
# 3                     Gestação / Pré-natal                 2408.47
# 4                                   Outros                  688.00
# 1  Alimentação Bebê / Introdução alimentar                  639.86
# 0                          Alergias / APLV                  314.12
# 2                      Amamentação / Leite                  101.82
# 7                 Suplementos / Nutrientes                   84.14
# 6                        Receitas / Comida                   67.33
# 5                          Perguntas / Q&A                   43.25
#
#    Media_Eng_Sem_Outliers
# 3                   75.64
# 4                   79.71
# 1                  101.50
# 0                   55.86
# 2                   85.19
# 7                   84.14
# 6                   67.33
# 5                   43.25
